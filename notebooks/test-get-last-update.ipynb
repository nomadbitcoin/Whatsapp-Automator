# %%
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
from time import sleep
from datetime import datetime
import pytz
import json

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))  # Add parent directory to Python path
from driver import Bot

from colorama import Fore, Style
from selenium.webdriver.common.keys import Keys 

# Initialize the bot
bot = Bot(session_name='anderson')

# Test login and chat counting functionality
print(Fore.GREEN + "Starting WhatsApp Web test..." + Style.RESET_ALL)
# Out:
# Starting WhatsApp Web test...

# %%
bot.login('+55')
# Out:
# Attempting to load WhatsApp Web...
# Waiting for QR code to be scanned...
# Attempting to load WhatsApp Web...
# Waiting for QR code to be scanned...
# Attempting to load WhatsApp Web...
# Logged in successfully!

# %%
def decode_latin(text):
    try:
        # Primeira tentativa: decodificar direto como utf-8
        return text.encode().decode('utf-8')
    except Exception as e1:
        try:
            # Segunda tentativa: decodificar caracteres unicode
            return bytes(text, 'utf-8').decode('unicode_escape')
        except Exception as e2:
            try:
                # Terceira tentativa: método original modificado
                return text.encode('raw_unicode_escape').decode('utf-8')
            except Exception as e3:
                print(f"Aviso: Não foi possível decodificar texto: '{text}'")
                print(f"Erros: {e1}, {e2}, {e3}")
                return text


def get_date_of_attach_msg(message):
    date = None
    time = None
    utc_dt = None

    try:
        # Pega a posição Y da mensagem atual
        message_location = message.location['y']

        # Procura todas as divs de data no container pai
        parent = message.find_element(By.XPATH, "./../../..")
        date_divs = parent.find_elements(By.CSS_SELECTOR, "div._amk4._amkb")

        # Encontra a div de data mais próxima acima da mensagem
        closest_date_div = None
        smallest_distance = float('inf')

        for date_div in date_divs:
            date_location = date_div.location['y']
            # Só considera datas que estão acima da mensagem
            if date_location < message_location:
                distance = message_location - date_location
                if distance < smallest_distance:
                    smallest_distance = distance
                    closest_date_div = date_div

        if closest_date_div:
            date = closest_date_div.text

        # Procura o horário em mensagens com anexo
        time_element = message.find_elements(
            By.CSS_SELECTOR, "span.x1rg5ohu.x16dsc37[dir='auto']")
        if time_element and time_element[0].text:
            time = time_element[0].text

        # Converte para UTC se tiver data e hora
        if date and time:
            local_tz = pytz.timezone('America/Sao_Paulo')
            datetime_str = f"{date} {time}"
            local_dt = datetime.strptime(datetime_str, "%d/%m/%Y %H:%M")
            local_dt = local_tz.localize(local_dt)
            utc_dt = local_dt.astimezone(pytz.UTC)

    except Exception as e:
        print(f"Erro ao processar data/hora: {e}")

    return utc_dt


def get_all_message_info(messages_elements):
    messages = []
    for message in messages_elements:
        try:
            time, date, sender, utc_dt = None, None, None, None

            # Verificar se existe mensagem citada
            quoted_message = None
            quoted_elements = message.find_elements(
                By.CSS_SELECTOR, "div[role='button'][aria-label='Quoted message']")
            if len(quoted_elements) > 0:
                try:
                    quoted_sender = quoted_elements[0].find_elements(
                        By.CSS_SELECTOR, "span[dir='auto']._ao3e")
                    quoted_text = quoted_elements[0].find_elements(
                        By.CSS_SELECTOR, "span.quoted-mention._ao3e")
                    if len(quoted_text) > 0:
                        quoted_message = {
                            "sender": quoted_sender[0].text if len(quoted_sender) > 0 else '',
                            "text": quoted_text[0].text
                        }
                except Exception as e:
                    print(f"Erro ao processar mensagem citada: {e}")

            # Verifica mensagem de texto
            copyable_text = message.find_elements(
                By.CSS_SELECTOR, ".copyable-text")
            text = ''
            if len(copyable_text) > 0:
                main_text_element = message.find_elements(
                    By.CSS_SELECTOR, "span.selectable-text.copyable-text")
                if len(main_text_element) > 0:  # Se encontrou algum elemento
                    try:
                        # Pega o texto do primeiro elemento
                        text = decode_latin(main_text_element[0].text.strip())
                    except Exception as e:
                        print(f"Erro ao processar mensagem main: {e}")

                date_text = copyable_text[0].get_attribute(
                    "data-pre-plain-text")
                if date_text:
                    # Extrai a data do formato '[HH:MM, DD/MM/YYYY] Nome: '
                    date_parts = date_text.split('] ')[
                        0].replace('[', '').split(', ')
                    time = date_parts[0]
                    date = date_parts[1]
                    sender = date_text.split('] ')[1].replace(': ', '')

                    # Convertendo para UTC
                    # Assumindo fuso horário de São Paulo
                    local_tz = pytz.timezone('America/Sao_Paulo')
                    datetime_str = f"{date} {time}"
                    local_dt = datetime.strptime(
                        datetime_str, "%d/%m/%Y %H:%M")
                    local_dt = local_tz.localize(local_dt)
                    utc_dt = local_dt.astimezone(pytz.UTC)

            attachment_data = None
            # TODO: Check date and time of the message when is attachment
            # Check for images
            image_elements = message.find_elements(
                By.CSS_SELECTOR, "img[data-testid='image-thumb'], img[class*='x15kfjtz']")
            if len(image_elements) > 0:
                utc_dt = get_date_of_attach_msg(message)
                attachment_data = None
                # attachment_data = process_image_attachment(
                #     image_elements[0])

            # Check for PDF
            pdf_elements = message.find_elements(
                By.CSS_SELECTOR, "div[role='button'][title^='Download']")
            if pdf_elements:
                utc_dt = get_date_of_attach_msg(message)
                attachment_data = None
                # attachment_data = process_pdf_attachment(pdf_elements[0])

            # Click download button if present
            download_audio_button = message.find_elements(
                By.CSS_SELECTOR, "button[aria-label='Download voice message']")
            if len(download_audio_button) > 0:
                download_audio_button[0].click()
                sleep(2)  # Wait for download to start

            # Check for voice message
            audio_play_button = message.find_elements(
                By.CSS_SELECTOR, 'button[aria-label="Play voice message"]')

            if audio_play_button:
                utc_dt = get_date_of_attach_msg(message)
                # Get duration before playing
                duration_element = message.find_elements(
                    By.CSS_SELECTOR, "div._ak8w")
                if len(duration_element) > 0:
                    duration_text = duration_element[0].text if duration_element else "0:00"
                else:
                    duration_text = "0:00"
                print(f"Audio Duration: {duration_text}")
                attachment_data = None
                # attachment_data = process_audio_attachment(
                #     audio_play_button, duration_text)

            message_data = {
                "text": text,
                "time": time,
                "date": date,
                "sender": sender,
                "quoted_message": quoted_message,
                "attachment_data": attachment_data,
                # TODO modificar se salvar em db
                "timestamp_utc": utc_dt.isoformat() if utc_dt else None,
            }
            print(message_data)

            messages.append(message_data)
        except Exception as e:
            print(f"Erro ao processar uma mensagem: {e}")
    return messages

# PEGAR TEXTO DA MENSAGEM


def get_all_messages():
    # Localize o contêiner da conversa
    conversation_container = bot.driver.find_element(
        By.XPATH, '//*[@id="main"]/div[3]/div/div[2]')

    previous_height = 0
    previous_message_count = 0
    messages_elements = []

    # Extraxt all messages
    while True:
        # Extraia mensagens atuais
        messages_elements = conversation_container.find_elements(
            By.CSS_SELECTOR, ".message-in, .message-out")

        # Se não houver novas mensagens após o scroll, sair do loop
        if len(messages_elements) == previous_message_count:
            break

        previous_message_count = len(messages_elements)

        # TODO VER FRASE EM PORTUGUES
        # TODO Pode ocorrer o problema "Couldn't get older messages. Open WhatsApp on your phone and click here to try again.""
        older_messages_button = bot.driver.find_elements(
            By.XPATH, "//button[.//div[contains(text(), 'Click here to get older messages from your phone.')]]")
        if len(older_messages_button) > 0:
            older_messages_button[0].click()
            sleep(10)

        print('Attempting to scroll')
        # bot.driver.execute_script(
        #     "arguments[0].scrollTop = arguments[0].scrollHeight;", conversation_container)
        # ou
        bot.driver.execute_script(
            "arguments[0].scrollTop = 0;", conversation_container)
        sleep(2)

    messages = get_all_message_info(messages_elements)
    print(messages)
    return list(messages)


# Coleta de mensagens
# all_messages = get_all_messages(conversation_container)

# Exibir mensagens coletadas
# for msg in all_messages:
#     print(msg)

# %%
def scroll_chats_list():
    chat_list_element = bot.driver.find_element(By.ID, "pane-side")
    bot.driver.execute_script(
        "arguments[0].scrollTop = arguments[0].scrollTop + 1000", chat_list_element)
    sleep(1)

# %%
from datetime import timedelta
import re

def has_to_update_chat_by_name(chat, name):
    # get contacts db
    last_date_elements = chat.find_elements(
                    By.XPATH, ".//div[@class='_ak8i']")
    if len(last_date_elements) == 0:
        last_date = None
        # return  
    else:   
        last_date = last_date_elements[0].text
        print(f'last_date: {last_date}')
        # can be a date DD/MM/YYYY when pass more than one week
        # or a time HH:MM if is today 
        # or a Day of the week(Saturday, Sunday, Monday, etc) if is less than one week
        if re.match(r'\d{2}/\d{2}/\d{4}', last_date):
            # date DD/MM/YYYY
            last_date = datetime.strptime(last_date, '%d/%m/%Y')
            # chek with contact if was atualize in the same day
        elif re.match(r'\d{2}:\d{2}', last_date): 
            # today HH:MM
            today = datetime.now()
            time = datetime.strptime(last_date, '%H:%M')
            last_date = today.replace(hour=time.hour, minute=time.minute)
            # check if contact was atualize in the same hour and day
        elif re.match(r'[A-Za-z]+', last_date): 
            # Last seen day of the week(Saturday, Sunday, Monday, etc)
            # For day names, calculate the most recent past occurrence of that day
            today = datetime.now()
            if last_date.lower() == 'yesterday':
                last_date = today - timedelta(days=1)
                # check if contact was atualize in the same day
            else:
                day_name = last_date
                # Convert day name to day number (0 = Monday, 6 = Sunday)
                target_day = datetime.strptime(day_name, '%A').weekday()
                current_day = today.weekday()
                
                # Calculate days difference
                days_diff = current_day - target_day
                if days_diff <= 0:  # If target day is ahead in the week
                    days_diff += 7
                
                # Subtract the difference to get the last occurrence
                last_date = today - timedelta(days=days_diff)
                # check if contact was atualize in the same day
       
        print(f'last_date normalized: {last_date}')

# %%
#bot.click_first_chat_and_scroll()
# GET ALL CONTACTS NAMES FROM CHATS LIST
# Localizar a lista de chats



all_chats = set()  # Usar set para evitar duplicatas
new_last_seen_name = None
last_seen_name = None  # Nome do último item visível na lista
# chat_list_element = bot.driver.find_element(By.ID, "pane-side")
while True:
    last_seen_name = new_last_seen_name
    # Encontrar os chats visíveis
    chat_items = bot.driver.find_elements(By.XPATH, "//div[@aria-label='Lista de conversas']//div[@role='listitem']")
    if len(chat_items) == 0:
        chat_items = bot.driver.find_elements(
            By.XPATH, "//div[@aria-label='Chat list']//div[@role='listitem']")

    # chat_items = bot.driver.find_elements(By.CLASS_NAME, "x10l6tqk")
    # new_last_seen_name = None
    
    # se todos os chats já foram coletados, sair do loop, checa todos os no
    
    # para teste somente 1 chat
    # chat_items = [chat_items[0], chat_items[1], chat_items[2],
    #               chat_items[3], chat_items[4], chat_items[5]]
    # chat_items = [chat_items[0]]
    print(f'len chat_items: {len(chat_items)}')
    for i, chat in enumerate(chat_items):
        try:
            # Captura o nome do chat e outras informações
            name = chat.find_element(By.XPATH, ".//span[@dir='auto']").text
            print(f'name: {name}')
            has_to_update_chat_by_name(chat, name)
            # Adicionar informações únicas ao conjunto
            if name not in all_chats:
                all_chats.add(f"{name}")
                # chat.click()
                # sleep(2)
            #     # get all messages and save in a file
            #     print(f'getting messages from {name}')
            #     messages = get_all_messages()
            #     print(f'messages: {messages}')
            #     with open(f"{name}.json", "w", encoding='utf-8') as f:
            #         json.dump(messages, f, ensure_ascii=False, indent=2)
            #     chat.click()
            #     sleep(2)
             
            
            # Atualiza o último nome visto no final da lista
            if i == len(chat_items) - 1:
                new_last_seen_name = name
                chat.click()
                sleep(2)
        except Exception as e:
            print(f"Erro ao processar um chat: {e}")
    
    if last_seen_name != None and new_last_seen_name == last_seen_name:
        break
    
    scroll_chats_list()
    # Fazer scroll para o último item
    # if chat_items:
    #     current_scroll = bot.driver.execute_script(
    #         "return arguments[0].scrollTop", chat_list_element)
    #     bot.driver.execute_script(
    #         "arguments[0].scrollTop = arguments[0].scrollTop + 1000", chat_list_element)
    #     sleep(2)  # Esperar o carregamento de novos chats

    # Condição de parada: o último nome não mudou
    # if new_last_seen_name == last_seen_name:
    #     break
    # last_seen_name = new_last_seen_name

print(all_chats)
print(len(all_chats))
# Out:
# len chat_items: 19
# name: Bel Isabel Faillace
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.147584
# name: +55 51 9633-8706
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.160138
# name: Yan Luiz
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.172198
# name: Grupo Erro Gostoso
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.184224
# name: Gabriel Rezende
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.196365
# name: Iza (Pedro)
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.209405
# name: Gui
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.221041
# name: +55 48 8851-9323
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.232469
# name: De repente 30 Andreza
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.244276
# name: Kaue Crypto Thai
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.255488
# name: Família BuscaPé
# last_date: Yesterday
# last_date normalized: 2025-01-21 09:14:00.266696
# name: Andreza Nox
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.279280
# name: ORIGENS 2025
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.291612
# name: Ano novo psicodélico
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.310139
# name: REUNIÃO REUNIÃO
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.322455
# name: +55 48 9221-0345
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.334190
# name: Let’s turn the bottle
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.346976
# name: Bruno Koerich
# last_date: Monday
# last_date normalized: 2025-01-20 09:14:00.359300
# name: Zucker Parish Family
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:00.370668
# len chat_items: 19
# name: Zucker Parish Family
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:03.645402
# name: Tibério corre florzinha
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:03.659333
# name: Alison Geremia (Eventos
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:03.672854
# name: Newton Pires
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:03.684688
# name: Renan Res
# last_date: Sunday
# last_date normalized: 2025-01-20 09:14:03.696976
# name: Amilcar Zanette @amkzanette
# last_date: Saturday
# last_date normalized: 2025-01-20 09:14:03.708772
# name: Praia Capão 21/12 22/12
# last_date: Friday
# last_date normalized: 2025-01-20 09:14:03.719573
# name: Coleira Buscapé
# last_date: Friday
# last_date normalized: 2025-01-20 09:14:03.732836
# name: Stack Sats with me
# last_date: Thursday
# last_date normalized: 2025-01-20 09:14:03.749336
# name: Luís Cláudio Staudt Conceição
# last_date: Thursday
# last_date normalized: 2025-01-20 09:14:03.763933
# name: Renati (Dinda)
# last_date: Thursday
# last_date normalized: 2025-01-20 09:14:03.777717
# name: Contador Direto - Financeiro
# last_date: Thursday
# last_date normalized: 2025-01-20 09:14:03.791720
# name: Clóvis Junior
# last_date: 15/01/2025
# last_date normalized: 2025-01-15 00:00:00
# name: +55 11 97850-6319
# last_date: 15/01/2025
# last_date normalized: 2025-01-15 00:00:00
# name: Gustavo Bromer
# last_date: 14/01/2025
# last_date normalized: 2025-01-14 00:00:00
# name: Thata Pereira
# last_date: 14/01/2025
# last_date normalized: 2025-01-14 00:00:00
# name: Infosul Cell
# last_date: 14/01/2025
# last_date normalized: 2025-01-14 00:00:00
# name: Nox / BBLaw - Infoprodutores
# last_date: 13/01/2025
# last_date normalized: 2025-01-13 00:00:00
# name: +55 41 9816-2171
# last_date: 13/01/2025
# last_date normalized: 2025-01-13 00:00:00
# len chat_items: 19
# name: +55 41 9816-2171
# last_date: 13/01/2025
# last_date normalized: 2025-01-13 00:00:00
# name: San  gás e água
# last_date: 13/01/2025
# last_date normalized: 2025-01-13 00:00:00
# name: Josi Thomé
# last_date: 11/01/2025
# last_date normalized: 2025-01-11 00:00:00
# name: Pedro Armond
# last_date: 11/01/2025
# last_date normalized: 2025-01-11 00:00:00
# name: Fabiane Krug Casa RT
# last_date: 11/01/2025
# last_date normalized: 2025-01-11 00:00:00
# name: +55 48 8456-6702
# last_date:
# last_date normalized:
# name: Tiago
# last_date:
# last_date normalized:
# name: Felipe Henrique
# last_date:
# last_date normalized:
# name: Mario
# last_date:
# last_date normalized:
# name: Gabriela Dias - N Bruno
# last_date:
# last_date normalized:
# name: Assistência Técnica Rip Curl
# last_date:
# last_date normalized:
# name: +55 51 3600-5552
# last_date:
# last_date normalized:
# name: lucas Devcon
# last_date:
# last_date normalized:
# name: WhatsApp
# last_date:
# last_date normalized:
# name: Estevan Wisoczynski Crypto CNX
# last_date:
# last_date normalized:
# name: +55 11 94785-6957
# last_date:
# last_date normalized:
# name: Matheus Griebler
# last_date:
# last_date normalized:
# name: Will Brother Du
# last_date:
# last_date normalized:
# name: +55 41 9597-1966
# last_date:
# last_date normalized:
# len chat_items: 19
# name: +55 41 9597-1966
# last_date:
# last_date normalized:
# name: FRETE CARLOS RÁPIDO E SEGURO.
# last_date:
# last_date normalized:
# name: +55 48 9634-3222
# last_date:
# last_date normalized:
# name: Rogério De Freitas Lima Frete Campeche Freitas Lima
# last_date:
# last_date normalized:
# name: +55 48 8837-4467
# last_date:
# last_date normalized:
# name: Ana Paula
# last_date:
# last_date normalized:
# name: Thome's praia
# last_date:
# last_date normalized:
# name: Ian Silva Lanni Floripa
# last_date:
# last_date normalized:
# name: Renan
# last_date:
# last_date normalized:
# name: Eric Sales Tuppers
# last_date:
# last_date normalized:
# name: Jesus Corre Jesus
# last_date:
# last_date normalized:
# name: Marlise Lottermann
# last_date:
# last_date normalized:
# name: Bruno Rangel
# last_date:
# last_date normalized:
# name: Ricardo Barbero
# last_date:
# last_date normalized:
# name: Luciane Thomé
# last_date:
# last_date normalized:
# name: WEB3DEV
# last_date:
# last_date normalized:
# name: Churras Retorno/ Casa Nova
# last_date:
# last_date normalized:
# name: +55 48 8805-8698
# last_date:
# last_date normalized:
# name: Simeri Wermuth
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Simeri Wermuth
# last_date:
# last_date normalized:
# name: Brasil na Devcon 7
# last_date:
# last_date normalized:
# name: +55 48 8854-4428
# last_date:
# last_date normalized:
# name: Fernanda Kirst
# last_date:
# last_date normalized:
# name: +55 48 8873-1179
# last_date:
# last_date normalized:
# name: Paulo Thome
# last_date:
# last_date normalized:
# name: Dilma
# last_date:
# last_date normalized:
# name: +55 51 8018-4811
# last_date:
# last_date normalized:
# name: +55 51 9346-1001
# last_date:
# last_date normalized:
# name: +55 11 99673-4419
# last_date:
# last_date normalized:
# name: Mari Prima
# last_date:
# last_date normalized:
# name: +55 83 9875-9355
# last_date:
# last_date normalized:
# name: Desapegos Drone Racer
# last_date:
# last_date normalized:
# name: Henrique Cezimbra
# last_date:
# last_date normalized:
# name: Satonomy Devs
# last_date:
# last_date normalized:
# name: +55 11 5039-7664
# last_date:
# last_date normalized:
# name: +55 48 8845-1866
# last_date:
# last_date normalized:
# name: +55 51 9770-1723
# last_date:
# last_date normalized:
# name: +55 11 97883-2287
# last_date:
# last_date normalized:
# len chat_items: 19
# name: +55 11 97883-2287
# last_date:
# last_date normalized:
# name: +55 47 9233-5596
# last_date:
# last_date normalized:
# name: +55 51 8195-5730
# last_date:
# last_date normalized:
# name: +55 11 5225-0552
# last_date:
# last_date normalized:
# name: +55 51 8270-8436
# last_date:
# last_date normalized:
# name: +55 51 9684-8394
# last_date:
# last_date normalized:
# name: Rafael K Borges
# last_date:
# last_date normalized:
# name: +55 51 9334-3585
# last_date:
# last_date normalized:
# name: Felipe Moura Kohl
# last_date:
# last_date normalized:
# name: felipe lottermann
# last_date:
# last_date normalized:
# name: Leonardo Gomes
# last_date:
# last_date normalized:
# name: João
# last_date:
# last_date normalized:
# name: Isabelle Peralta Sofá Campeche Peralta
# last_date:
# last_date normalized:
# name: Jonathas Uber App Imobiliária Vendedor
# last_date:
# last_date normalized:
# name: Claudio Garmatz Arrumou Persiana Casa Garmatz
# last_date:
# last_date normalized:
# name: +55 48 8817-5481
# last_date:
# last_date normalized:
# name: @rafaestefan Amigo Newton Mkt
# last_date:
# last_date normalized:
# name: Alemao Continente/Centro Rain
# last_date:
# last_date normalized:
# name: Rosa Maria Krug Albuquerq Casa RT
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Rosa Maria Krug Albuquerq Casa RT
# last_date:
# last_date normalized:
# name: Yasmin Casa RT
# last_date:
# last_date normalized:
# name: +55 21 99553-2182
# last_date:
# last_date normalized:
# name: +55 48 8429-3586
# last_date:
# last_date normalized:
# name: +55 48 9111-3223
# last_date:
# last_date normalized:
# name: Goodbye Summer, goodbye Mario. See u soon
# last_date:
# last_date normalized:
# name: Floripa Family Casa Campeche
# last_date:
# last_date normalized:
# name: +55 11 5194-3199
# last_date:
# last_date normalized:
# name: +55 48 9904-2891
# last_date:
# last_date normalized:
# name: Dezirre Nox
# last_date:
# last_date normalized:
# name: Alice Reis
# last_date:
# last_date normalized:
# name: Dickcock Devcon Haus
# last_date:
# last_date normalized:
# name: +55 48 9654-4823
# last_date:
# last_date normalized:
# name: ETHFLN - Floripa crew
# last_date:
# last_date normalized:
# name: +973 3831 6673
# last_date:
# last_date normalized:
# name: Fucking Asia
# last_date:
# last_date normalized:
# name: +55 24 3025-8132
# last_date:
# last_date normalized:
# name: +55 11 97484-9856
# last_date:
# last_date normalized:
# name: Flix
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Flix
# last_date:
# last_date normalized:
# name: Guitar Airbnb Pattaya
# last_date:
# last_date normalized:
# name: +66 63 218 0008
# last_date:
# last_date normalized:
# name: Baill Pattaya
# last_date:
# last_date normalized:
# name: Gabriel Thom Devcon Thai
# last_date:
# last_date normalized:
# name: Thiago Grinch
# last_date:
# last_date normalized:
# name: +55 11 5039-0444
# last_date:
# last_date normalized:
# name: Antonio Neto Devcon Thai
# last_date:
# last_date normalized:
# name: +55 48 8492-0797
# last_date:
# last_date normalized:
# name: +66 81 479 2755
# last_date:
# last_date normalized:
# name: Parler
# last_date:
# last_date normalized:
# name: +66 81 684 1977
# last_date:
# last_date normalized:
# name: Iza Novicki
# last_date:
# last_date normalized:
# name: PEDRO CALABREZ - O MAPA #075
# last_date:
# last_date normalized:
# name: +55 31 8500-5645
# last_date:
# last_date normalized:
# name: +55 11 91068-7395
# last_date:
# last_date normalized:
# name: +55 11 1011-2816
# last_date:
# last_date normalized:
# name: Surtida Chiang Mai T
# last_date:
# last_date normalized:
# name: Solange Gueiros Chainlink
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Solange Gueiros Chainlink
# last_date:
# last_date normalized:
# name: +55 19 98200-3296
# last_date:
# last_date normalized:
# name: +55 51 9617-8712
# last_date:
# last_date normalized:
# name: +55 68 9292-4308
# last_date:
# last_date normalized:
# name: +55 31 4042-7299
# last_date:
# last_date normalized:
# name: +82 10-8174-1017
# last_date:
# last_date normalized:
# name: +66 85 099 7263
# last_date:
# last_date normalized:
# name: +66 86 056 4543
# last_date:
# last_date normalized:
# name: Topazio/API/NOX TRADING
# last_date:
# last_date normalized:
# name: +55 19 98178-0305
# last_date:
# last_date normalized:
# name: +55 47 9655-4887
# last_date:
# last_date normalized:
# name: Cousins
# last_date:
# last_date normalized:
# name: Sabrina (Cast One)
# last_date:
# last_date normalized:
# name: BB
# last_date:
# last_date normalized:
# name: Shopee
# last_date:
# last_date normalized:
# name: Machado e Costa advocacia
# last_date:
# last_date normalized:
# name: +55 21 97544-3188
# last_date:
# last_date normalized:
# name: +55 51 9117-6532
# last_date:
# last_date normalized:
# name: haran mnm2626 Uber Chang Mai
# last_date:
# last_date normalized:
# len chat_items: 19
# name: haran mnm2626 Uber Chang Mai
# last_date:
# last_date normalized:
# name: weedmed
# last_date:
# last_date normalized:
# name: Silvana Nunes Sqque
# last_date:
# last_date normalized:
# name: +56 9 8967 2852
# last_date:
# last_date normalized:
# name: Mateus Iotti
# last_date:
# last_date normalized:
# name: +55 48 9648-1666
# last_date:
# last_date normalized:
# name: José Ribeiro Floripa Role
# last_date:
# last_date normalized:
# name: Fagner
# last_date:
# last_date normalized:
# name: O Retorno do Grandalhão
# last_date:
# last_date normalized:
# name: Arrumar Celular Rio Tavares
# last_date:
# last_date normalized:
# name: +11. NOVO VALOR
# last_date:
# last_date normalized:
# name: +55 48 93618-5351
# last_date:
# last_date normalized:
# name: ACNUR Brasil
# last_date:
# last_date normalized:
# name: +55 12 97612-8203
# last_date:
# last_date normalized:
# name: Zé Surf
# last_date:
# last_date normalized:
# name: Ian Ayad
# last_date:
# last_date normalized:
# name: Soluções Core
# last_date:
# last_date normalized:
# name: +55 48 9661-2059
# last_date:
# last_date normalized:
# name: The Members / NoxPay
# last_date:
# last_date normalized:
# len chat_items: 19
# name: The Members / NoxPay
# last_date:
# last_date normalized:
# name: Lidia RT
# last_date:
# last_date normalized:
# name: william fedrizzi
# last_date:
# last_date normalized:
# name: Transfer Sympla
# last_date:
# last_date normalized:
# name: Matheus Frederich Saque
# last_date:
# last_date normalized:
# name: +55 48 9947-4327
# last_date:
# last_date normalized:
# name: Vinicius NTech Arrumar Notebook Pc Celular Rio Tavares
# last_date:
# last_date normalized:
# name: Casa Canto Lagoa 1 Quarto Mobiliada 1200
# last_date:
# last_date normalized:
# name: Gueu
# last_date:
# last_date normalized:
# name: Carla Costureira Anão Biquinis Bia
# last_date:
# last_date normalized:
# name: +55 48 4042-3042
# last_date:
# last_date normalized:
# name: Rômulo Miara De Sordi Surf
# last_date:
# last_date normalized:
# name: +55 48 9649-1207
# last_date:
# last_date normalized:
# name: Michel Reparo Prancha
# last_date:
# last_date normalized:
# name: WEB3DEV
# last_date:
# last_date normalized:
# name: Jeová Tikehau
# last_date:
# last_date normalized:
# name: +55 51 9336-6730
# last_date:
# last_date normalized:
# name: Vinícius Maciel Nox
# last_date:
# last_date normalized:
# name: Shawã Tuví Jaguar
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Shawã Tuví Jaguar
# last_date:
# last_date normalized:
# name: Izi
# last_date:
# last_date normalized:
# name: Lucas Bassotto Nox
# last_date:
# last_date normalized:
# name: Filipe Smaniotto Saque
# last_date:
# last_date normalized:
# name: +55 48 3307-9337
# last_date:
# last_date normalized:
# name: +55 48 9200-4448
# last_date:
# last_date normalized:
# name: +55 48 8447-6212
# last_date:
# last_date normalized:
# name: +55 48 8831-2111
# last_date:
# last_date normalized:
# name: +55 48 9695-9625
# last_date:
# last_date normalized:
# name: +55 48 9108-8454
# last_date:
# last_date normalized:
# name: +55 48 8836-5286
# last_date:
# last_date normalized:
# name: +55 48 8501-1400
# last_date:
# last_date normalized:
# name: +55 48 9219-8845
# last_date:
# last_date normalized:
# name: +55 31 8270-8587
# last_date:
# last_date normalized:
# name: Bianca Coutinho Surf
# last_date:
# last_date normalized:
# name: +55 11 2377-8619
# last_date:
# last_date normalized:
# name: +55 48 9150-1364
# last_date:
# last_date normalized:
# name: +55 18 99643-3233
# last_date:
# last_date normalized:
# name: +55 48 9691-5426
# last_date:
# last_date normalized:
# len chat_items: 19
# name: +55 48 9691-5426
# last_date:
# last_date normalized:
# name: +55 12 99792-8810
# last_date:
# last_date normalized:
# name: +55 48 9956-4282
# last_date:
# last_date normalized:
# name: +55 48 9175-0033
# last_date:
# last_date normalized:
# name: +55 48 9647-6223
# last_date:
# last_date normalized:
# name: +55 11 5196-1749
# last_date:
# last_date normalized:
# name: +55 48 9179-0035
# last_date:
# last_date normalized:
# name: +55 48 9183-9027
# last_date:
# last_date normalized:
# name: +55 48 9183-6797
# last_date:
# last_date normalized:
# name: +55 48 9653-1620
# last_date:
# last_date normalized:
# name: +55 11 93905-8748
# last_date:
# last_date normalized:
# name: +55 48 8474-6468
# last_date:
# last_date normalized:
# name: Luiz Henrique Saque
# last_date:
# last_date normalized:
# name: Ortiz Gaming / NoxPay
# last_date:
# last_date normalized:
# name: Settee / NoxPay
# last_date:
# last_date normalized:
# name: Cristiano Offish.co
# last_date:
# last_date normalized:
# name: +55 48 8405-3546
# last_date:
# last_date normalized:
# name: Casa Olx Campeche 3quartod
# last_date:
# last_date normalized:
# name: +55 48 9102-1364
# last_date:
# last_date normalized:
# len chat_items: 19
# name: +55 48 9102-1364
# last_date:
# last_date normalized:
# name: Nox Global | Ferramentas | | XG00 Rodrix
# last_date:
# last_date normalized:
# name: +55 48 8447-1700
# last_date:
# last_date normalized:
# name: Societário - Contador Direto
# last_date:
# last_date normalized:
# name: Félix RT
# last_date:
# last_date normalized:
# name: Marina Raphaldini Surf
# last_date:
# last_date normalized:
# name: Isis Ceroni
# last_date:
# last_date normalized:
# name: Unisinos
# last_date:
# last_date normalized:
# name: +55 44 9995-5675
# last_date:
# last_date normalized:
# name: Henrique Peres Saque
# last_date:
# last_date normalized:
# name: +55 48 9128-8878
# last_date:
# last_date normalized:
# name: Neta Honorata
# last_date:
# last_date normalized:
# name: Ricardo Barbero
# last_date:
# last_date normalized:
# name: +55 48 9805-1276
# last_date:
# last_date normalized:
# name: +55 48 9936-8954
# last_date:
# last_date normalized:
# name: +55 47 9679-1256
# last_date:
# last_date normalized:
# name: +55 48 9913-5076
# last_date:
# last_date normalized:
# name: Tech Leads club
# last_date:
# last_date normalized:
# name: Flix
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Flix
# last_date:
# last_date normalized:
# name: +55 48 9901-3089
# last_date:
# last_date normalized:
# name: +55 51 9618-3576
# last_date:
# last_date normalized:
# name: Andre Henrique
# last_date:
# last_date normalized:
# name: Jordana Surf
# last_date:
# last_date normalized:
# name: Tech Leads club
# last_date:
# last_date normalized:
# name: Anna Bida
# last_date:
# last_date normalized:
# name: Jonathan Dube
# last_date:
# last_date normalized:
# name: Aventuras Místicas
# last_date:
# last_date normalized:
# name: Maciel Surf
# last_date:
# last_date normalized:
# name: +55 31 7601-1101
# last_date:
# last_date normalized:
# name: +55 800 006 1101
# last_date:
# last_date normalized:
# name: Nox
# last_date:
# last_date normalized:
# name: Vitória Tamarindo Nox
# last_date:
# last_date normalized:
# name: Nox
# last_date:
# last_date normalized:
# name: +55 11 99152-8071
# last_date:
# last_date normalized:
# name: One Piece
# last_date:
# last_date normalized:
# name: Agroleste Agropet
# last_date:
# last_date normalized:
# name: +55 11 3230-0110
# last_date:
# last_date normalized:
# len chat_items: 19
# name: +55 11 3230-0110
# last_date:
# last_date normalized:
# name: Agropet Empório Rio Tavares
# last_date:
# last_date normalized:
# name: +55 11 4040-3152
# last_date:
# last_date normalized:
# name: +55 48 9150-3908
# last_date:
# last_date normalized:
# name: Integração NoxPay / Botgram
# last_date:
# last_date normalized:
# name: Michael Ferreira Nox
# last_date:
# last_date normalized:
# name: Isadora Roos
# last_date:
# last_date normalized:
# name: Uriel
# last_date:
# last_date normalized:
# name: Polones
# last_date:
# last_date normalized:
# name: Rachel Cossi
# last_date:
# last_date normalized:
# name: +55 13 99635-6287
# last_date:
# last_date normalized:
# name: Jairo Chapada
# last_date:
# last_date normalized:
# name: João Chapada Casal
# last_date:
# last_date normalized:
# name: Marcelo Pulo Chapada
# last_date:
# last_date normalized:
# name: Paula Chapeu
# last_date:
# last_date normalized:
# name: +55 61 9254-2292
# last_date:
# last_date normalized:
# name: Tiago
# last_date:
# last_date normalized:
# name: +55 48 9913-0808
# last_date:
# last_date normalized:
# name: Samantha Salgueiro Cunhas
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Samantha Salgueiro Cunhas
# last_date:
# last_date normalized:
# name: Letícia Pereira Nox
# last_date:
# last_date normalized:
# name: +55 48 8870-9318
# last_date:
# last_date normalized:
# name: +55 62 9913-9880
# last_date:
# last_date normalized:
# name: +55 61 9509-6666
# last_date:
# last_date normalized:
# name: Joao Reges Hostel Alto Paraíso
# last_date:
# last_date normalized:
# name: +55 24 99869-8564
# last_date:
# last_date normalized:
# name: +55 61 8102-5806
# last_date:
# last_date normalized:
# name: +55 64 9268-2222
# last_date:
# last_date normalized:
# name: +55 11 99481-3325
# last_date:
# last_date normalized:
# name: Cenira Restaurante Calunga
# last_date:
# last_date normalized:
# name: +55 55 9173-4695
# last_date:
# last_date normalized:
# name: +55 67 9240-2633
# last_date:
# last_date normalized:
# name: +55 11 91086-7962
# last_date:
# last_date normalized:
# name: Geobazzi - Eng. Leandro Bazzi Chapada Alto
# last_date:
# last_date normalized:
# name: Alysson Chapada
# last_date:
# last_date normalized:
# name: +55 83 8815-2929
# last_date:
# last_date normalized:
# name: +55 11 4949-8922
# last_date:
# last_date normalized:
# name: +55 62 9670-5017
# last_date:
# last_date normalized:
# len chat_items: 21
# name: +55 62 9670-5017
# last_date:
# last_date normalized:
# name: Nathan Rebechi Cardoso
# last_date:
# last_date normalized:
# name: +55 51 9228-7223
# last_date:
# last_date normalized:
# name: +55 53 8131-1908
# last_date:
# last_date normalized:
# name: André - NoxPay Business
# last_date:
# last_date normalized:
# name: +55 14 98125-6805
# last_date:
# last_date normalized:
# name: Glória NOX
# last_date:
# last_date normalized:
# name: Alvaro Oliveira
# last_date:
# last_date normalized:
# name: Cesar NOX
# last_date:
# last_date normalized:
# name: +55 14 99882-1814
# last_date:
# last_date normalized:
# name: +55 24 93500-6842
# last_date:
# last_date normalized:
# name: +55 48 93300-9302
# last_date:
# last_date normalized:
# name: +55 45 8813-8650
# last_date:
# last_date normalized:
# name: André Spolaor NOX
# last_date:
# last_date normalized:
# name: Projetos Digitais & Nox
# last_date:
# last_date normalized:
# name: +55 42 9812-8420
# last_date:
# last_date normalized:
# name: Bárbara Cardoso
# last_date:
# last_date normalized:
# name: +55 51 8936-4075
# last_date:
# last_date normalized:
# name: DESPEDIDA
# last_date:
# last_date normalized:
# name: Futebol hoje 22 30
# last_date:
# last_date normalized:
# name: Maicon Machado Rocha
# last_date:
# last_date normalized:
# len chat_items: 20
# name: Maicon Machado Rocha
# last_date:
# last_date normalized:
# name: 0xagon Head Quarters
# last_date:
# last_date normalized:
# name: +55 51 8596-9098
# last_date:
# last_date normalized:
# name: +55 48 9122-1649
# last_date:
# last_date normalized:
# name: +55 12 98811-1663
# last_date:
# last_date normalized:
# name: Transfer Gateway <-> OTC - NOX
# last_date:
# last_date normalized:
# name: WEB3DEV
# last_date:
# last_date normalized:
# name: Piber Dev Poa Cb Tiago Alemão
# last_date:
# last_date normalized:
# name: +55 48 9838-2717
# last_date:
# last_date normalized:
# name: +55 48 8492-9554
# last_date:
# last_date normalized:
# name: +55 48 8465-3565
# last_date:
# last_date normalized:
# name: Marli Marmita RT
# last_date:
# last_date normalized:
# name: Matheus Carvalho Nox
# last_date:
# last_date normalized:
# name: VMDL
# last_date:
# last_date normalized:
# name: +55 48 9104-6867
# last_date:
# last_date normalized:
# name: +55 48 9900-2584
# last_date:
# last_date normalized:
# name: Soma Cogumelos
# last_date:
# last_date normalized:
# name: +55 34 9160-6368
# last_date:
# last_date normalized:
# name: Cerimônia Dia 30 Casa N’Bosque￼
# last_date:
# last_date normalized:
# name: +44 7974 045725
# last_date:
# last_date normalized:
# len chat_items: 21
# name: +44 7974 045725
# last_date:
# last_date normalized:
# name: Ativa Play Fitness
# last_date:
# last_date normalized:
# name: Paulo Galo Amigo Gui Sc
# last_date:
# last_date normalized:
# name: Bea Rio Tavares
# last_date:
# last_date normalized:
# name: +55 48 9170-8606
# last_date:
# last_date normalized:
# name: +55 32 9991-0621
# last_date:
# last_date normalized:
# name: BOM PAY+NOX
# last_date:
# last_date normalized:
# name: Dra. Natália Avante
# last_date:
# last_date normalized:
# name: Douglas Cardoso Saque
# last_date:
# last_date normalized:
# name: +55 48 9991-6931
# last_date:
# last_date normalized:
# name: 27 voltas em uma rocha flutuante aleatória no universo
# last_date:
# last_date normalized:
# name: Pedro NOX
# last_date:
# last_date normalized:
# name: +55 31 7353-2088
# last_date:
# last_date normalized:
# name: +55 37 9824-2776
# last_date:
# last_date normalized:
# name: +55 11 99476-9352
# last_date:
# last_date normalized:
# name: NOX Estudo Melhorias Rodrix
# last_date:
# last_date normalized:
# name: Yas Correia
# last_date:
# last_date normalized:
# name: +55 67 9963-4831
# last_date:
# last_date normalized:
# name: +55 48 8482-9124
# last_date:
# last_date normalized:
# name: LIVE HOJE #311
# last_date:
# last_date normalized:
# name: PRJN - PROJECTUS NEW
# last_date:
# last_date normalized:
# len chat_items: 21
# name: PRJN - PROJECTUS NEW
# last_date:
# last_date normalized:
# name: Thomas Nox
# last_date:
# last_date normalized:
# name: +55 13 98868-8543
# last_date:
# last_date normalized:
# name: +55 48 9647-2133
# last_date:
# last_date normalized:
# name: +55 48 9936-2795
# last_date:
# last_date normalized:
# name: +55 51 8109-4000
# last_date:
# last_date normalized:
# name: +55 21 3950-4387
# last_date:
# last_date normalized:
# name: Yan Luis
# last_date:
# last_date normalized:
# name: +852 6564 6527
# last_date:
# last_date normalized:
# name: +55 47 9612-1331
# last_date:
# last_date normalized:
# name: Lacerda
# last_date:
# last_date normalized:
# name: Mergulho Consciente Hugo Omar
# last_date:
# last_date normalized:
# name: Noxpay.io
# last_date:
# last_date normalized:
# name: Cynthia @parler_agencia (Agência Parler)
# last_date:
# last_date normalized:
# name: Juan Beck Barra
# last_date:
# last_date normalized:
# name: Aniversário Dudu
# last_date:
# last_date normalized:
# name: +55 48 9107-3972
# last_date:
# last_date normalized:
# name: +55 15 99648-8225
# last_date:
# last_date normalized:
# name: +44 7308 290830
# last_date:
# last_date normalized:
# name: +55 48 3879-7050
# last_date:
# last_date normalized:
# name: Mah casa 5 Ruas Olx
# last_date:
# last_date normalized:
# len chat_items: 21
# name: Mah casa 5 Ruas Olx
# last_date:
# last_date normalized:
# name: +55 48 8424-3783
# last_date:
# last_date normalized:
# name: Mercado Livre
# last_date:
# last_date normalized:
# name: Lucrando com Dados  | 01 a 07 de abril - 20h #13
# last_date:
# last_date normalized:
# name: Arregadão Lanches
# last_date:
# last_date normalized:
# name: +55 14 98213-2902
# last_date:
# last_date normalized:
# name: +55 48 9107-7604
# last_date:
# last_date normalized:
# name: Ana Castilho Aya Micro
# last_date:
# last_date normalized:
# name: Christian Frühauf
# last_date:
# last_date normalized:
# name: Turing Gringa
# last_date:
# last_date normalized:
# name: João Nox
# last_date:
# last_date normalized:
# name: Vinícius Eduardo Nox
# last_date:
# last_date normalized:
# name: Raul Carvalho Nox
# last_date:
# last_date normalized:
# name: +55 11 98588-3490
# last_date:
# last_date normalized:
# name: +55 27 99693-1616
# last_date:
# last_date normalized:
# name: +55 31 7601-1100
# last_date:
# last_date normalized:
# name: Tao Zanella Unisul Php
# last_date:
# last_date normalized:
# name: +55 48 9197-1860
# last_date:
# last_date normalized:
# name: Eric
# last_date:
# last_date normalized:
# name: +55 51 9101-3056
# last_date:
# last_date normalized:
# name: Klebão Marques (Brommer)
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Lucrando com Dados  | 01 a 07 de abril - 20h #13
# last_date:
# last_date normalized:
# name: Arregadão Lanches
# last_date:
# last_date normalized:
# name: +55 14 98213-2902
# last_date:
# last_date normalized:
# name: +55 48 9107-7604
# last_date:
# last_date normalized:
# name: Ana Castilho Aya Micro
# last_date:
# last_date normalized:
# name: Christian Frühauf
# last_date:
# last_date normalized:
# name: Turing Gringa
# last_date:
# last_date normalized:
# name: João Nox
# last_date:
# last_date normalized:
# name: Vinícius Eduardo Nox
# last_date:
# last_date normalized:
# name: Raul Carvalho Nox
# last_date:
# last_date normalized:
# name: +55 11 98588-3490
# last_date:
# last_date normalized:
# name: +55 27 99693-1616
# last_date:
# last_date normalized:
# name: +55 31 7601-1100
# last_date:
# last_date normalized:
# name: Tao Zanella Unisul Php
# last_date:
# last_date normalized:
# name: +55 48 9197-1860
# last_date:
# last_date normalized:
# name: Eric
# last_date:
# last_date normalized:
# name: +55 51 9101-3056
# last_date:
# last_date normalized:
# name: Klebão Marques (Brommer)
# last_date:
# last_date normalized:
# name: Guilherme Salomão Nox
# last_date:
# last_date normalized:
# len chat_items: 19
# name: Lucrando com Dados  | 01 a 07 de abril - 20h #13
# last_date:
# last_date normalized:
# name: Arregadão Lanches
# last_date:
# last_date normalized:
# name: +55 14 98213-2902
# last_date:
# last_date normalized:
# name: +55 48 9107-7604
# last_date:
# last_date normalized:
# name: Ana Castilho Aya Micro
# last_date:
# last_date normalized:
# name: Christian Frühauf
# last_date:
# last_date normalized:
# name: Turing Gringa
# last_date:
# last_date normalized:
# name: João Nox
# last_date:
# last_date normalized:
# name: Vinícius Eduardo Nox
# last_date:
# last_date normalized:
# name: Raul Carvalho Nox
# last_date:
# last_date normalized:
# name: +55 11 98588-3490
# last_date:
# last_date normalized:
# name: +55 27 99693-1616
# last_date:
# last_date normalized:
# name: +55 31 7601-1100
# last_date:
# last_date normalized:
# name: Tao Zanella Unisul Php
# last_date:
# last_date normalized:
# name: +55 48 9197-1860
# last_date:
# last_date normalized:
# name: Eric
# last_date:
# last_date normalized:
# name: +55 51 9101-3056
# last_date:
# last_date normalized:
# name: Klebão Marques (Brommer)
# last_date:
# last_date normalized:
# name: Guilherme Salomão Nox
# last_date:
# last_date normalized:
# {'+55 48 9904-2891', '+55 48 9111-3223', '+55 51 9346-1001', '+55 48 9913-5076', '+55 48 93618-5351', '+55 51 9633-8706', 'Jesus Corre Jesus', 'Cesar NOX', '+55 14 98213-2902', '+55 48 9102-1364', 'Ian Silva Lanni Floripa', 'Churras Retorno/ Casa Nova', '+55 48 9947-4327', '+55 21 3950-4387', 'Mateus Iotti', 'Jonathan Dube', 'One Piece', 'PEDRO CALABREZ - O MAPA #075', 'Gustavo Bromer', '+55 48 9900-2584', '+55 11 5196-1749', '+55 34 9160-6368', '+55 11 3230-0110', 'Matheus Griebler', '+55 13 98868-8543', 'Bel Isabel Faillace', 'Samantha Salgueiro Cunhas', '+55 48 9901-3089', '+55 51 8936-4075', 'Antonio Neto Devcon Thai', 'Filipe Smaniotto Saque', 'Yas Correia', '+55 14 99882-1814', 'Satonomy Devs', 'Stack Sats with me', '+55 51 9228-7223', 'Vitória Tamarindo Nox', 'Polones', 'Nox Global | Ferramentas | | XG00 Rodrix', '+55 48 9648-1666', 'Gabriel Thom Devcon Thai', 'Maicon Machado Rocha', '+55 12 99792-8810', 'Alice Reis', '+55 13 99635-6287', '+55 48 8424-3783', '+55 51 9334-3585', 'Rachel Cossi', '+55 53 8131-1908', '+55 48 9913-0808', '+55 51 8018-4811', '+55 48 8870-9318', '+55 48 9661-2059', '+55 12 97612-8203', 'Marli Marmita RT', '+55 61 9509-6666', '+55 48 8805-8698', '+44 7974 045725', 'Fernanda Kirst', 'Lidia RT', 'Renan Res', '+55 11 97883-2287', 'Agropet Empório Rio Tavares', 'The Members / NoxPay', 'Yan Luiz', 'Ortiz Gaming / NoxPay', '+55 51 8109-4000', 'REUNIÃO REUNIÃO', '+55 48 9197-1860', 'Felipe Henrique', '+55 11 91068-7395', '+55 11 5039-7664', 'Soluções Core', 'Amilcar Zanette @amkzanette', 'Gueu', '+44 7308 290830', 'Alemao Continente/Centro Rain', 'Henrique Peres Saque', 'Integração NoxPay / Botgram', '+55 48 9956-4282', 'Paulo Thome', '+55 48 8873-1179', 'João', '+852 6564 6527', 'Mercado Livre', 'Cerimônia Dia 30 Casa N’Bosque￼', 'Maciel Surf', '+55 47 9679-1256', 'Michel Reparo Prancha', '+55 48 9179-0035', 'Luiz Henrique Saque', 'Estevan Wisoczynski Crypto CNX', 'Arregadão Lanches', 'Simeri Wermuth', 'Iza (Pedro)', 'Soma Cogumelos', '+55 48 8492-9554', 'Assistência Técnica Rip Curl', '0xagon Head Quarters', '+55 11 5225-0552', '+55 800 006 1101', '+55 19 98178-0305', '+55 51 9117-6532', '+55 48 8429-3586', '+55 48 9634-3222', 'WhatsApp', '+55 15 99648-8225', 'Rafael K Borges', 'Douglas Cardoso Saque', 'Matheus Carvalho Nox', 'Sabrina (Cast One)', 'Thiago Grinch', 'Ricardo Barbero', 'Fabiane Krug Casa RT', 'Floripa Family Casa Campeche', 'Ana Castilho Aya Micro', '+55 51 9684-8394', '+55 48 8474-6468', '+55 48 8831-2111', 'Futebol hoje 22 30', 'José Ribeiro Floripa Role', 'Transfer Sympla', 'Coleira Buscapé', '+55 21 99553-2182', '+55 48 9991-6931', '+55 11 91086-7962', 'Transfer Gateway <-> OTC - NOX', 'Luciane Thomé', '+55 11 99152-8071', '+55 11 99673-4419', 'Vinícius Eduardo Nox', '+55 11 5194-3199', '+55 47 9233-5596', '@rafaestefan Amigo Newton Mkt', 'Marina Raphaldini Surf', '+55 48 9200-4448', '+55 11 99476-9352', '+55 48 3879-7050', 'lucas Devcon', '+55 51 8270-8436', 'BOM PAY+NOX', 'Yasmin Casa RT', '+55 41 9816-2171', 'Renan', 'william fedrizzi', '+55 48 8482-9124', 'Infosul Cell', '+66 63 218 0008', 'Jordana Surf', 'Jairo Chapada', '+11. NOVO VALOR', '+55 31 4042-7299', '+55 62 9913-9880', '+55 67 9963-4831', 'Matheus Frederich Saque', '+55 18 99643-3233', 'Agroleste Agropet', '+55 61 9254-2292', 'Marlise Lottermann', '+55 51 8596-9098', 'Ativa Play Fitness', 'WEB3DEV', '+973 3831 6673', 'Solange Gueiros Chainlink', 'Geobazzi - Eng. Leandro Bazzi Chapada Alto', 'Gabriel Rezende', 'Cristiano Offish.co', 'Pedro Armond', '+55 51 9770-1723', 'Glória NOX', '+55 27 99693-1616', 'Brasil na Devcon 7', 'Pedro NOX', '+55 41 9597-1966', '+55 31 7353-2088', '+55 48 93300-9302', 'Alvaro Oliveira', 'Christian Frühauf', '+55 48 9936-8954', '+55 24 99869-8564', '+55 83 9875-9355', '+55 48 9128-8878', 'ACNUR Brasil', 'Félix RT', 'Yan Luis', '+55 11 4040-3152', 'Praia Capão 21/12 22/12', 'Claudio Garmatz Arrumou Persiana Casa Garmatz', 'Felipe Moura Kohl', '+55 24 3025-8132', 'André Spolaor NOX', 'ETHFLN  ...
# 400
